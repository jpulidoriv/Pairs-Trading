# %%
import yfinance as yf
import pandas as pd
from pandas_datareader import data as pdr
import datetime as dt
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
stocks_data = pd.DataFrame()

# %%
ticker_data = yf.download([
    'AAPL', 'AMGN', 'AXP', 'BA', 'CAT', 'CRM', 'CSCO', 'CVX', 'DIS', 'DOW',
    'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'JPM', 'KO', 'MCD', 'MMM',
    'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'V', 'VZ', 'WBA', 'WMT'
], start = "2024-01-01", end = "2024-12-31", auto_adjust = False)
stocks_data = pd.concat([stocks_data, ticker_data])
# Out:
# [*********************100%***********************]  30 of 30 completed

# %%
stocks_data
# Out:
# Price        Adj Close                                                  \
# Ticker            AAPL        AMGN         AXP          BA         CAT
# Date
# 2024-01-02  184.290421  283.845764  185.031128  251.759995  285.661652
# 2024-01-03  182.910538  286.995453  183.075806  243.910004  277.454163
# 2024-01-04  180.587540  289.362518  184.475571  244.940002  279.210876
# 2024-01-05  179.862839  289.200256  186.368240  249.000000  281.972656
# 2024-01-08  184.210999  296.721344  186.516113  229.000000  285.212769
# ...                ...         ...         ...         ...         ...
# 2024-12-23  254.655716  259.590149  297.112762  177.690002  362.310883
# 2024-12-24  257.578674  260.071930  301.746460  179.339996  364.472504
# 2024-12-26  258.396667  258.783813  302.273438  180.380005  364.026276
# 2024-12-27  254.974930  258.262665  299.350037  180.720001  361.785309
# 2024-12-30  251.593079  254.968643  295.651031  176.550003  359.950928
#
# ...

# %%
adj_close = stocks_data['Adj Close']
adj_close
# Out:
# Ticker            AAPL        AMGN         AXP          BA         CAT  \
# Date
# 2024-01-02  184.290421  283.845764  185.031128  251.759995  285.661652
# 2024-01-03  182.910538  286.995453  183.075806  243.910004  277.454163
# 2024-01-04  180.587540  289.362518  184.475571  244.940002  279.210876
# 2024-01-05  179.862839  289.200256  186.368240  249.000000  281.972656
# 2024-01-08  184.210999  296.721344  186.516113  229.000000  285.212769
# ...                ...         ...         ...         ...         ...
# 2024-12-23  254.655716  259.590149  297.112762  177.690002  362.310883
# 2024-12-24  257.578674  260.071930  301.746460  179.339996  364.472504
# 2024-12-26  258.396667  258.783813  302.273438  180.380005  364.026276
# 2024-12-27  254.974930  258.262665  299.350037  180.720001  361.785309
# 2024-12-30  251.593079  254.968643  295.651031  176.550003  359.950928
#
# Ticker             CRM       CSCO         CVX         DIS        DOW  ...  \
# ...

# %%
corr_matrix = adj_close.corr()
corr_matrix
# Out:
# Ticker      AAPL      AMGN       AXP        BA       CAT       CRM      CSCO  \
# Ticker
# AAPL    1.000000  0.442935  0.800100 -0.563565  0.509909  0.211817  0.637520
# AMGN    0.442935  1.000000  0.128079 -0.233074 -0.000400 -0.554158 -0.108113
# AXP     0.800100  0.128079  1.000000 -0.805561  0.865591  0.518073  0.765786
# BA     -0.563565 -0.233074 -0.805561  1.000000 -0.823202 -0.232631 -0.483290
# CAT     0.509909 -0.000400  0.865591 -0.823202  1.000000  0.563169  0.679649
# CRM     0.211817 -0.554158  0.518073 -0.232631  0.563169  1.000000  0.780370
# CSCO    0.637520 -0.108113  0.765786 -0.483290  0.679649  0.780370  1.000000
# CVX    -0.060448 -0.258338  0.323417 -0.311807  0.477450  0.273189  0.107731
# DIS    -0.301303 -0.847976  0.140061 -0.026748  0.306596  0.648890  0.219906
# DOW    -0.720678  0.082967 -0.634582  0.297128 -0.316948 -0.586394 -0.787073
# GS      0.873291  0.240656  0.953299 -0.744743  0.753570  0.428062  0.742334
# ...

# %%
plt.figure(figsize=(20, 18)) 
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Correlation Matrix of Adjusted Close Prices")
plt.show()
